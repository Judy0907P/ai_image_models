# %%
# 1. GPU runtime: Runtime → Change runtime type → GPU

# 2. Clone your repo (private? use a token)
# !git clone https://github.com/Judy0907P/ai_image_models.git
# %cd ai_image_models

# %%
# 3. Install package + deps
# !pip install -e . --no-deps
# !pip install einops wandb tqdm datasets matplotlib timm pytorch-ignite kagglehub
# only if imports fail / versions are wrong:
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu124
# if torch isn't right for Colab GPU yet:
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu124

# 4. Make sure CIFAR data exists where train.py expects it
#    (01_train/data/cifar10) — upload, download, or regenerate the same way you did locally

# %%
# 5. Login (paste API key from https://wandb.ai/authorize)
import wandb
wandb.login()

# %%
# 6. Continue THE SAME sweep (do not wandb sweep again)
# %cd 07_final
# !wandb agent jiayizhai0907-city-college-of-san-francisco/ai_image_models-07_final/96gw72ka
